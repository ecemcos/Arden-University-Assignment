# %%
import numpy as np
P0 = 1000
r = 0.03

t = np.linspace(0, 20, 201)
P = P0 * np.exp(r*t)
dP_dt = r*P

P_20 = P0 * np.exp(r*20)
growth_20 = r*P_20

print("Paris Population Growth Model")
print("------------------------------")

print(f"Population at t = 20 years: {round(P_20, 3)}")
print(f"Growth rate at t = 20 years: {round(growth_20, 3)}")
# Out:
# Paris Population Growth Model
# ------------------------------
# Population at t = 20 years: 1822.119
# Growth rate at t = 20 years: 54.664
